# %% [markdown]
# # Time Series Workshop &minus; Walkthrough
#
# ODSC East &minus; April 15, 2020
#
# Mark Steadman
# Viktor Kovryzhkin
#
# https://github.com/vikua/ts-workshop

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator, RegressorMixin
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## Example Time Series Data Set

# %%
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
plt.figure(figsize=(9,3))
plt.plot(data.date, data.y, '.-', c='gray')

t_diff_median = data.date.diff().median()
print('Average time step: {!s}'.format(t_diff_median))
# Out:
# Average time step: 31 days 00:00:00

# %% [markdown]
# ## Fitting a Model

# %%
def fit_model(t, X, y, distance, test_size=0.2, log_transform=False, estimator=None, plot=False):
    
    # apply forecast distance
    X = X.shift(distance)
    
    # ignore missing value rows
    non_null = X.dropna(how='any').index.values

    # create holdout set
    if isinstance(test_size, float):
        test_size = int(test_size * len(t))
    train = non_null[:-test_size]
    test  = non_null[-test_size:]

    # standardize
    numeric_cols = X.select_dtypes(include=[np.number]).columns
    centers = X.loc[train, numeric_cols].mean(axis=0)
    scales = np.maximum(1e-15, X.loc[train, numeric_cols].std(axis=0))
    X[numeric_cols] = (X[numeric_cols] - centers)/scales
    
    # fit model
    if estimator is None:
        estimator = ElasticNetCV(n_alphas=100, l1_ratio=0.9, cv=5, random_state=123)
    if log_transform:
        estimator = MultiplicativeEstimator(estimator)
    estimator.fit(X.loc[train, :], y[train])
    test_score = estimator.score(X.loc[test, :], y[test])

    # plot the fit
    if plot:
        plt.figure(figsize=(9,3))
        plt.plot(t, y, '.', c='gray', alpha=0.7)
        plt.plot(t[train], estimator.predict(X.loc[train, :]), 'b-', lw=2, alpha=0.7)
        plt.plot(t[test], estimator.predict(X.loc[test, :]),  'r-', lw=2, alpha=0.7)
        plt.annotate('Test Score: {}'.format(test_score), 
                     xy=(0, 1), xytext=(12, -12), va='top', 
                     xycoords='axes fraction', textcoords='offset points')
        plt.show()
    return estimator, test_score


def feature_importance_summary(model):
    if hasattr(model, 'coef_'):
        coef = pd.Series(model.coef_, index=X.columns, name='Importance')
        importances = coef.abs()
        importances.sort_values(ascending=False, inplace=True)
        importances = importances[importances > 1e-15]
        display(importances.to_frame().style.bar())
    else:
        raise NotImplemented('Only linear models supported at the momemnt.')
        

class MultiplicativeEstimator(BaseEstimator, RegressorMixin):
    
    def __init__(self, estimator):
        self.estimator = estimator
        
    def fit(self, X, y, *args, **kwargs):
        self.estimator.fit(X, np.log(y), *args, **kwargs)
        return self
    
    def predict(self, X):
        return np.exp(self.estimator.predict(X))
    
    def __getattr__(self, name):
        return getattr(self.estimator, name)

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# create features in new dataframe
X = pd.DataFrame()
X['lag 0'] = y.shift(0)
X['lag 1'] = y.shift(1)
X['lag 2'] = y.shift(2)
X['lag 3'] = y.shift(3)
X['lag 4'] = y.shift(4)
X['lag 5'] = y.shift(5)
X['lag 6'] = y.shift(6)
X['lag 7'] = y.shift(7)
X['lag 8'] = y.shift(8)
X['lag 9'] = y.shift(9)
X['lag 10'] = y.shift(10)
X['lag 11'] = y.shift(11)
X['lag 12'] = y.shift(12)

# fit
model, score = fit_model(t, X, y, plot=True, distance=12)

# display importances
feature_importance_summary(model)
# Out:
# <style  type="text/css" >
#     #T_1165eefc_7f1e_11ea_a352_88e9fe625754row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.6%, transparent 71.6%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.2%, transparent 37.2%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.6%, transparent 23.6%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.3%, transparent 11.3%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_1165eefc_7f1e_11ea_a352_88e9fe625754row8_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_1165eefc_7f1e_11ea_a352_88e9fe625754" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Importance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row0" class="row_heading level0 row0" >lag 0</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row0_col0" class="data row0 col0" >37.510400</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row1" class="row_heading level0 row1" >lag 12</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row1_col0" class="data row1 col0" >26.977104</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row2" class="row_heading level0 row2" >lag 1</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row2_col0" class="data row2 col0" >14.207411</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row3" class="row_heading level0 row3" >lag 11</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row3_col0" class="data row3 col0" >9.169339</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row4" class="row_heading level0 row4" >lag 8</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row4_col0" class="data row4 col0" >4.591760</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row5" class="row_heading level0 row5" >lag 9</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row5_col0" class="data row5 col0" >1.613833</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row6" class="row_heading level0 row6" >lag 7</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row6_col0" class="data row6 col0" >1.429615</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row7" class="row_heading level0 row7" >lag 2</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row7_col0" class="data row7 col0" >0.958577</td>
#             </tr>
#             <tr>
#                         <th id="T_1165eefc_7f1e_11ea_a352_88e9fe625754level0_row8" class="row_heading level0 row8" >lag 3</th>
#                         <td id="T_1165eefc_7f1e_11ea_a352_88e9fe625754row8_col0" class="data row8 col0" >0.403940</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Number of Lags

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']
X = pd.DataFrame()

lag_counts = range(0, 20)
scores = []

for i in lag_counts:
    X['lag {}'.format(i)] = y.shift(i)
    model, score = fit_model(t, X, y, distance=12)
    scores.append(score)
    
plt.figure()
plt.plot(lag_counts, scores, lw=2)
plt.xlabel('# of Lags')
plt.ylabel('Test Score')
# Out:
# Text(0, 0.5, 'Test Score')

# %% [markdown]
# ## More Types of Features

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# create features in new dataframe
X = pd.DataFrame()
X['lag 0'] = y.shift(0)
X['lag 1'] = y.shift(1)
X['lag 2'] = y.shift(2)
X['lag 3'] = y.shift(3)
X['lag 4'] = y.shift(4)
X['lag 5'] = y.shift(5)
X['lag 6'] = y.shift(6)
X['lag 7'] = y.shift(7)
X['lag 8'] = y.shift(8)
X['lag 9'] = y.shift(9)
X['lag 10'] = y.shift(10)
X['lag 11'] = y.shift(11)
X['lag 12'] = y.shift(12)
X['t'] = (t - t.min())/(t.max() - t.min())
X['rolling mean 3'] = y.rolling(3).mean()
X['rolling mean 6'] = y.rolling(6).mean()
X['rolling mean 12'] = y.rolling(12).mean()
X['rolling std 12'] = y.rolling(12).std()
X['rolling min 12'] = y.rolling(12).min()
X['rolling max 12'] = y.rolling(12).max()
X['rolling median 12'] = y.rolling(12).median()

model, score = fit_model(t, X, y, plot=True, distance=12)

feature_importance_summary(model)
# Out:
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# <style  type="text/css" >
#     #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.1%, transparent 61.1%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.1%, transparent 50.1%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.1%, transparent 35.1%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.8%, transparent 16.8%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 9.3%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 9.3%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 9.3%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.8%, transparent 7.8%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.3%, transparent 6.3%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.4%, transparent 5.4%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#         }    #T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row16_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Importance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row0" class="row_heading level0 row0" >lag 0</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row0_col0" class="data row0 col0" >45.918042</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row1" class="row_heading level0 row1" >t</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row1_col0" class="data row1 col0" >28.049816</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row2" class="row_heading level0 row2" >lag 12</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row2_col0" class="data row2 col0" >23.029791</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row3" class="row_heading level0 row3" >rolling min 12</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row3_col0" class="data row3 col0" >16.150069</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row4" class="row_heading level0 row4" >lag 11</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row4_col0" class="data row4 col0" >7.709228</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row5" class="row_heading level0 row5" >rolling mean 3</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row5_col0" class="data row5 col0" >5.102925</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row6" class="row_heading level0 row6" >lag 2</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row6_col0" class="data row6 col0" >4.843827</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row7" class="row_heading level0 row7" >lag 1</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row7_col0" class="data row7 col0" >4.306312</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row8" class="row_heading level0 row8" >rolling max 12</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row8_col0" class="data row8 col0" >4.288974</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row9" class="row_heading level0 row9" >lag 7</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row9_col0" class="data row9 col0" >4.286845</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row10" class="row_heading level0 row10" >lag 9</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row10_col0" class="data row10 col0" >3.945216</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row11" class="row_heading level0 row11" >lag 8</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row11_col0" class="data row11 col0" >3.604727</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row12" class="row_heading level0 row12" >lag 4</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row12_col0" class="data row12 col0" >3.397272</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row13" class="row_heading level0 row13" >lag 10</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row13_col0" class="data row13 col0" >2.893230</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row14" class="row_heading level0 row14" >rolling std 12</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754row14_col0" class="data row14 col0" >2.501314</td>
#             </tr>
#             <tr>
#                         <th id="T_13bcd1e8_7f1e_11ea_a352_88e9fe625754level0_row15" class="row_heading level0 row15" >lag 6</th>
#                         <td id="T_13bcd1e8_7f1e_11ea_a352_8

# %% [markdown]
# # Time Learning Curve

# %%
row_counts = range(X.shape[0] // 2, X.shape[0] + 1)
scores = []

for n in row_counts:
    recent = X.index[-n:]
    model, score = fit_model(t.loc[recent], X.loc[recent, :], y.loc[recent], distance=12)
    scores.append(score)

plt.figure()
plt.plot(100.0*np.array(row_counts)/X.shape[0], scores, lw=2)
plt.axhline(max(scores), linestyle='--', color='gray')
plt.xlabel('% recent rows')
plt.ylabel('Test Score')

plt.figure(figsize=(9,3))
plt.plot(t, y, '-', lw=2)
plt.axvline(t.iloc[-np.argmax(row_counts)], linestyle='--', color='gray')
# Out:
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232.68284614994718, tolerance: 32.11585423728813
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234.75229212619888, tolerance: 32.35621833333334
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 358.3593750062555, tolerance: 28.152898333333336
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 403.5010424887096, tolerance: 28.68450819672132
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 434.872589706526, tolerance: 29.714388709677415
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 718.9406392937708, tolerance: 30.855085714285718
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 658.4534921399463, tolerance: 31.7995609375
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1427.7209211420723, tolerance: 31.7542984375
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1405.421113999444, tolerance: 33.243544615384614
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1425.6686486299877, tolerance: 34.760103030303036
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1343.2942067321928, tolerance: 36.78046268656717
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1382.397796887366, tolerance: 37.97428676470588
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 926.6301694171216, tolerance: 37.594023529411764
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1132.4607022027776, tolerance: 37.79150724637682
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1303.408159982011, tolerance: 38.05923428571429
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367.0087605931667, tolerance: 38.57561971830986
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1548.396001081247, tolerance: 39.294
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 762.7423608605359, tolerance: 39.18286527777778
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 749.1466803929434, tolerance: 39.73663287671233
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 728.0199788567797, tolerance: 41.01651486486486
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 609.330738912231, tolerance: 42.26226666666666
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 499.1787898859893, tolerance: 43.519393421052634
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 689.4530789649489, tolerance: 44.21400394736842
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 671.3580162157305, tolerance: 45.43674285714286
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 567.2536261402674, tolerance: 46.269698717948714
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 561.0532539038122, tolerance: 46.598179746835456
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643.2567122222863, tolerance: 47.06763875
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 668.5831816552763, tolerance: 47.49698875000001
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 966.0745377966396, tolerance: 48.77015061728395
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1099.6198838856562, tolerance: 50.056962195121955
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1072.3680285826931, tolerance: 51.05966746987952
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1021.7955000418733, tolerance: 52.31089523809524
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1054.9846849929636, tolerance: 53.239470238095244
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 839.6916953705841, tolerance: 54.73312470588235
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 823.7047897920584, tolerance: 56.71190348837211
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 832.7143708554213, tolerance: 58.228126436781615
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 879.0388523888341, tolerance: 59.22518977272728
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 775.9619173812935, tolerance: 59.62538977272726
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 803.8487936264573, tolerance: 60.301894382022475
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 783.6934899833323, tolerance: 61.34666222222222
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 823.9127095199456, tolerance: 62.49266153846154
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 813.3820099466739, tolerance: 63.81130760869564
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1064.7464738214785, tolerance: 64.66902065217393
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1040.8294050004006, tolerance: 66.23386451612903
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1065.8547532146385, tolerance: 67.89098297872341
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1065.8547532146385, tolerance: 67.89098297872341
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1065.8547532146385, tolerance: 67.89098297872341
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1022.7422199255252, tolerance: 67.14416989247313
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1022.7422199255252, tolerance: 67.14416989247313
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1022.7422199255252, tolerance: 67.14416989247313
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1022.7422199255252, tolerance: 67.14416989247313
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1022.7422199255252, tolerance: 67.14416989247313
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)

# %% [markdown]
# ## Forecast Distance

# %%
distances = range(0, 36)
scores = []

for i in distances:
    model, score = fit_model(t, X, y, distance=i)
    scores.append(score)

plt.figure()
plt.plot(distances, scores, lw=2)
plt.xlabel('Forecast Distance')
plt.ylabel('Test Score')
# Out:
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1053.238344678036, tolerance: 82.01305242718449
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1170.3140726711827, tolerance: 80.28192549019606
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1136.2389592212203, tolerance: 78.89437029702972
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2299.009333744654, tolerance: 77.331956
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1203.525075536354, tolerance: 75.47409898989899
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1011.5723495400016, tolerance: 74.1844
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2128.9329604530585, tolerance: 73.30789690721652
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1682.6988831785702, tolerance: 72.41313333333333
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.1404104239591, tolerance: 71.25437894736844
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1089.5301180121496, tolerance: 69.46099680851064
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 684.071380091571, tolerance: 67.07547311827956
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.1939247549653, tolerance: 65.38598586956523
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3070.657462731897, tolerance: 62.28239555555557
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2059.397247936964, tolerance: 61.36162471910112
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1611.3455397364487, tolerance: 60.104398863636355
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2845.480484154722, tolerance: 59.015381609195416
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1628.8387849820901, tolerance: 58.02480581395348
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1843.6414689767043, tolerance: 57.39168941176471
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1437.0394624970759, tolerance: 56.743498809523814
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 655.9454512859029, tolerance: 55.8110265060241
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 807.3787961455391, tolerance: 54.37417195121951
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 668.4263728318492, tolerance: 52.48524691358025
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 825.2197690290031, tolerance: 46.44507368421052
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1501.935618598658, tolerance: 45.257354666666664
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2218.2980971860134, tolerance: 44.69170405405406
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301.09798842918826, tolerance: 44.280167123287676
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.71466546084048, tolerance: 42.11448714285714
#   positive)
# /Users/mark/.virtualenvs/py3-talk/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 485.18679056118344, tolerance: 40.502782608695654
#   positive)
# Text(0, 0.5, 'Test Score')

# %% [markdown]
# ## Log Transform / Differencing

# %%
# read the data
data = pd.read_csv('data/air_passengers.csv', parse_dates=['date'])
t = data['date']
y = data['y']

# normal
plt.figure(figsize=(9,3))
plt.plot(t, y)
plt.ylabel('Normal')

# differencing
plt.figure(figsize=(9,3))
plt.plot(t, y - y.shift(12), 'r')
plt.ylabel('12 Month Differenced')

# log transform
log_y = y.apply(np.log)
plt.figure(figsize=(9,3))
plt.plot(t, log_y, 'g');
plt.ylabel('Log Transformed')

# both
plt.figure(figsize=(9,3))
plt.plot(t, log_y - log_y.shift(12), 'm')
plt.ylabel('Differenced and Log Transformed')
# Out:
# Text(0, 0.5, 'Differenced and Log Transformed')
